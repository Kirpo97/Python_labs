# %% [markdown]
# # Лабараторная работа 1

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
# %matplotlib inline

# %% [markdown]
# # Cписок

# %%
tickers_list = ['GAZP.ME', 'ROSN.ME', 'YNDX.ME']
data = pd.DataFrame(columns=tickers_list)
for ticker in tickers_list:
    data[ticker] = yf.download(ticker,'2021-01-01','2022-08-01')['Adj Close']
    
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend(['Газпром', 'Роснефть', 'Яндекс'], title='легенда')
plt.title("График 1", fontsize=16)
plt.ylabel('цена (x*100)', fontsize=14)
plt.xlabel('год', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Словарь

# %%
tickers_dict = {1:'ADBE',2:'YNDX.ME'}
data = pd.DataFrame(columns=tickers_dict)

data[1] = yf.download(tickers_dict[1],'2014-01-01','2022-08-01')['Adj Close']
data[2] = yf.download(tickers_dict[2],'2014-01-01','2022-08-01')['Adj Close']
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

plt.legend(['Adobe', 'Яндекс'], title='легенда')
plt.title("График 2", fontsize=16)
plt.ylabel('цена (x*100)', fontsize=14)
plt.xlabel('год', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Кортеж

# %%
tickers_tuple = ('ADS.DE','BABA')
data = pd.DataFrame(columns=tickers_tuple)

for ticker2 in tickers_tuple:
    data[ticker2] = yf.download(ticker2,'2015-01-01','2022-08-01')['Adj Close']
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

plt.legend(['Adidas', 'Alibaba'], title='легенда')
plt.title("График 3", fontsize=16)
plt.ylabel('цена (x*100)', fontsize=14)
plt.xlabel('год', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Множество

# %%
tickers_num = {'MOEX.ME','SPBE.ME'}
data = pd.DataFrame(columns=tickers_tuple)

for ticker2 in tickers_tuple:
    data[ticker2] = yf.download(ticker2,'2013-01-01','2022-08-01')['Adj Close']
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

plt.legend(['Московская Биржа', 'СПБ Биржа'], title='легенда')
plt.title("График 3", fontsize=16)
plt.ylabel('цена (x*100)', fontsize=14)
plt.xlabel('год', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
