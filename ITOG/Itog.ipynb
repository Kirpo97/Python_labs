# %% [markdown]
# # Лабараторная работа №3

# %%
import pandas as pd
import numpy as np
import time
from tqdm.autonotebook import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

from tslearn.clustering import TimeSeriesKMeans
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import yfinance as yf

# %% [markdown]
# # Задача 1: получение данных

# %%
def get_info(ticker_obj):
    info_keys = ['shortName','sector','indusrty','coutry','market']
    info_values = []
    for key in info_keys:
        info_values.append(ticker_obj.info.get(key, None))
    return dict(zip(info_keys, info_values))

# %%
GAZP = yf.Ticker('GOLF')
GAZP.history()
plt.plot(GAZP.history())
# Out:
# [<matplotlib.lines.Line2D at 0x1b496ab74f0>,
#  <matplotlib.lines.Line2D at 0x1b498e005b0>,
#  <matplotlib.lines.Line2D at 0x1b498e00b80>,
#  <matplotlib.lines.Line2D at 0x1b498e00670>,
#  <matplotlib.lines.Line2D at 0x1b498e00b20>,
#  <matplotlib.lines.Line2D at 0x1b498e006a0>,
#  <matplotlib.lines.Line2D at 0x1b498e00cd0>]

# %%
all_tickers = pd.read_csv(
    'https://raw.githubusercontent.com/shilewenuw/get_all_tickers/master/get_all_tickers/tickers.csv', 
    header=None,
    error_bad_lines=False
)

all_tickers = all_tickers.values.reshape(-1)
print(len(all_tickers))
print(all_tickers[:4])
# Out:
# C:\Users\Кирилл\AppData\Local\Temp\ipykernel_11008\621757785.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   all_tickers = pd.read_csv(
# 2762
# ['DDD' 'MMM' 'WBAI' 'WUBA']

# %%
get_info(GAZP)
# Out:
# {'shortName': 'Acushnet Holdings Corp.',
#  'sector': 'Consumer Cyclical',
#  'indusrty': None,
#  'coutry': None,
#  'market': 'us_market'}

# %%
trending = pd.read_html("https://finance.yahoo.com/trending-tickers")[0]
#most_active = pd.read_html("https://finance.yahoo.com/most-active")[0]
gainers = pd.read_html("https://finance.yahoo.com/gainers")[0]
losers = pd.read_html("https://finance.yahoo.com/losers")[0]

# %%
interesting_tickers = set()

for df in [trending, gainers, losers]:
    interesting_tickers = interesting_tickers.union(set(df['Symbol']))
    
interesting_tickers = list(interesting_tickers)
interesting_tickers[:3]
# Out:
# ['SQM', 'KSS', 'PLNT']

# %%
len(interesting_tickers)
# Out:
# 69

# %%
full_ticker_data = []

for ticker in tqdm(interesting_tickers):
    try:
        ticker_obj = yf.Ticker(ticker)
        close_price = ticker_obj.history(period='3mo')['Close'].to_dict()
        info = get_info(ticker_obj)
        info.update(close_price)
        full_ticker_data.append(info)
    except:
        continue
        
full_ticker_df = pd.DataFrame(full_ticker_data)
# Out:
# 100%|██████████| 69/69 [10:17<00:00,  8.94s/it]

# %%
full_ticker_df
# Out:
#                           shortName                  sector indusrty coutry  \
# 0    Sociedad Quimica y Minera S.A.         Basic Materials     None   None
# 1                Kohl's Corporation       Consumer Cyclical     None   None
# 2              Planet Fitness, Inc.       Consumer Cyclical     None   None
# 3   Take-Two Interactive Software,   Communication Services     None   None
# 4   LATAM AIRLINES GROUP SA SPONS A             Industrials     None   None
# ..                              ...                     ...      ...    ...
# 64                   Medtronic plc.              Healthcare     None   None
# 65                AMTD Digital Inc.              Technology     None   None
# 66               Vertex Energy, Inc                  Energy     None   None
# 67                         Fabrinet              Technology     None   None
# 68      DigitalOcean Holdings, Inc.              Technology     None   None
#
#        market  2022-08-08 00:00:00-04:00  2022-08-09 00:00:00-04:00  \
# 0   us_market                  94.216454                  95.559883
# 1   us_market                  30.935141                  29.184839
# 2   us_market                  81.089996                  76.449997
# 3   us_market                 125.510002                 120.760002
# 4   us_market                   0.274460                   0.274460
# ..        ...                        ...                        ...
# 64  us_market                  93.580002                  93.099998
# 65  us_market                 405.000000                 212.000000
# 66  us_market                  13.980000                   7.800000
# 67  us_market                  96.169998                  94.000000
# 68  us_market                  47.869999                  47.150002
#
#     2022-08-10 00:00:00-04:00  2022-08-11 00:00:00-04:00  \
# 0                   99.158699                  99.805901
# 1                   30.807310                  32.075787
# 2                   77.110001                  74.709999
# 3                  123.790001                 120.669998
# 4                    0.274460                   0.285732
# ..                        ...                        ...
# 64                  94.169998                  94.040001
# 65                 217.600006                 214.000000
# 66                   7.930000                   7.050000
# 67                  97.540001                  97.989998
# 68                  52.669998                  47.520000
#
#     2022-08-12 00:00:00-04:00  ...  2022-10-14 00:00:00-03:00  \
# 0                  106.591675  ...                        NaN
# 1                   32.626446  ...                        NaN
# 2                   76.690002  ...                        NaN
# 3                  123.139999  ...                        NaN
# 4                    0.294476  ...                        NaN
# ..                        ...  ...                        ...
# 64                  94.820000  ...                        NaN
# 65                 192.270004  ...                        NaN
# 66                   7.300000  ...                        NaN
# 67                 100.660004  ...                        NaN
# 68                  48.759998  ...                        NaN
#
#     2022-10-17 00:00:00-03:00  2022-10-18 00:00:00-03:00  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 68                        NaN                        NaN
#
#     2022-10-19 00:00:00-03:00  2022-10-20 00:00:00-03:00  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 68                        NaN                        NaN
#
#     2022-10-21 00:00:00-03:00  2022-10-24 00:00:00-03:00  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 68                        NaN                        NaN
#
#     2022-10-25 00:00:00-03:00  2022-10-26 00:00:00-03:00  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 68                        NaN                        NaN
#
#     2022-10-27 00:00:00-03:00
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 64                        NaN
# 65                        NaN
# 66                        NaN
# 67                        NaN
# 68                        NaN
#
# [69 rows x 221 columns]

# %%
full_ticker_df
# Out:
#                           shortName                  sector indusrty coutry  \
# 0    Sociedad Quimica y Minera S.A.         Basic Materials     None   None
# 1                Kohl's Corporation       Consumer Cyclical     None   None
# 2              Planet Fitness, Inc.       Consumer Cyclical     None   None
# 3   Take-Two Interactive Software,   Communication Services     None   None
# 4   LATAM AIRLINES GROUP SA SPONS A             Industrials     None   None
# ..                              ...                     ...      ...    ...
# 64                   Medtronic plc.              Healthcare     None   None
# 65                AMTD Digital Inc.              Technology     None   None
# 66               Vertex Energy, Inc                  Energy     None   None
# 67                         Fabrinet              Technology     None   None
# 68      DigitalOcean Holdings, Inc.              Technology     None   None
#
#        market  2022-08-08 00:00:00-04:00  2022-08-09 00:00:00-04:00  \
# 0   us_market                  94.216454                  95.559883
# 1   us_market                  30.935141                  29.184839
# 2   us_market                  81.089996                  76.449997
# 3   us_market                 125.510002                 120.760002
# 4   us_market                   0.274460                   0.274460
# ..        ...                        ...                        ...
# 64  us_market                  93.580002                  93.099998
# 65  us_market                 405.000000                 212.000000
# 66  us_market                  13.980000                   7.800000
# 67  us_market                  96.169998                  94.000000
# 68  us_market                  47.869999                  47.150002
#
#     2022-08-10 00:00:00-04:00  2022-08-11 00:00:00-04:00  \
# 0                   99.158699                  99.805901
# 1                   30.807310                  32.075787
# 2                   77.110001                  74.709999
# 3                  123.790001                 120.669998
# 4                    0.274460                   0.285732
# ..                        ...                        ...
# 64                  94.169998                  94.040001
# 65                 217.600006                 214.000000
# 66                   7.930000                   7.050000
# 67                  97.540001                  97.989998
# 68                  52.669998                  47.520000
#
#     2022-08-12 00:00:00-04:00  ...  2022-10-14 00:00:00-03:00  \
# 0                  106.591675  ...                        NaN
# 1                   32.626446  ...                        NaN
# 2                   76.690002  ...                        NaN
# 3                  123.139999  ...                        NaN
# 4                    0.294476  ...                        NaN
# ..                        ...  ...                        ...
# 64                  94.820000  ...                        NaN
# 65                 192.270004  ...                        NaN
# 66                   7.300000  ...                        NaN
# 67                 100.660004  ...                        NaN
# 68                  48.759998  ...                        NaN
#
#     2022-10-17 00:00:00-03:00  2022-10-18 00:00:00-03:00  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 68                        NaN                        NaN
#
#     2022-10-19 00:00:00-03:00  2022-10-20 00:00:00-03:00  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 68                        NaN                        NaN
#
#     2022-10-21 00:00:00-03:00  2022-10-24 00:00:00-03:00  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 68                        NaN                        NaN
#
#     2022-10-25 00:00:00-03:00  2022-10-26 00:00:00-03:00  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ..                        ...                        ...
# 64                        NaN                        NaN
# 65                        NaN                        NaN
# 66                        NaN                        NaN
# 67                        NaN                        NaN
# 68                        NaN                        NaN
#
#     2022-10-27 00:00:00-03:00
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 64                        NaN
# 65                        NaN
# 66                        NaN
# 67                        NaN
# 68                        NaN
#
# [69 rows x 221 columns]

# %%
scaler = StandardScaler()
tickers_scaled = scaler.fit_transform(full_ticker_df.iloc[:, 5:].T).T

# %%
plt.plot(tickers_scaled.T);

# %% [markdown]
# # Задача 2: Обучение сети

# %% [markdown]
# # Basic KMeans

# %%
distortions = []
silhouette = []
K = range(1, 10)
for k in tqdm(K):
    kmeanModel = TimeSeriesKMeans(n_clusters=k, metric="euclidean", n_jobs=6, max_iter=10)
    kmeanModel.fit(tickers_scaled)
    distortions.append(kmeanModel.inertia_)
    if k > 1:
        silhouette.append(silhouette_score(tickers_scaled, kmeanModel.labels_))

plt.figure(figsize=(10,4))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Elbow Method')
plt.show()

plt.figure(figsize=(10,4))
plt.plot(K[1:], silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhouette score')
plt.title('Silhouette')
plt.show()
# Out:
#  11%|█         | 1/9 [00:01<00:11,  1.39s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [22], line 9
#       7     distortions.append(kmeanModel.inertia_)
#       8     if k > 1:
# ----> 9         silhouette.append(silhouette_score(tickers_scaled, kmeanModel.labels_))
#      11 plt.figure(figsize=(10,4))
#      12 plt.plot(K, distortions, 'bx-')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\cluster\_unsupervised.py:117, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115     else:
#     116         X, labels = X[indices], labels[indices]
# --> 117 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\cluster\_unsupervised.py:212, in silhouette_samples(X, labels, metric, **kwds)
#     152 def silhouette_samples(X, labels, *, metric="euclidean", **kwds):
#     153     """Compute the Silhouette Coefficient for each sample.
#     154
#     155     The Silhouette Coefficient is a measure of how well samples are clustered
#    (...)
#     210        <https://en.wikipedia.org/wiki/Silhouette_(clustering)>`_
#     211     """
# --> 212     X, labels = check_X_y(X, labels, accept_sparse=["csc", "csr"])
#     214     # Check for non-zero diagonal entries in precomputed distance matrix
#     215     if metric == "precomputed":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains NaN.

# %% [markdown]
# # DTW

# %%
distortions = []
silhouette = []
K = range(1, 10)
for k in tqdm(K):
    kmeanModel = TimeSeriesKMeans(n_clusters=k, metric="dtw", n_jobs=6, max_iter=10)
    kmeanModel.fit(tickers_scaled)
    distortions.append(kmeanModel.inertia_)
    if k > 1:
        silhouette.append(silhouette_score(tickers_scaled, kmeanModel.labels_))

plt.figure(figsize=(10,4))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Elbow Method')
plt.show()

plt.figure(figsize=(10,4))
plt.plot(K[1:], silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhouette score')
plt.title('Silhouette')
plt.show()
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]C:\Users\Кирилл\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tslearn\barycenters\dba.py:596: RuntimeWarning: invalid value encountered in double_scalars
#   if abs(cost_prev - cost) < tol:
#   0%|          | 0/9 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [23], line 6
#       4 for k in tqdm(K):
#       5     kmeanModel = TimeSeriesKMeans(n_clusters=k, metric="dtw", n_jobs=6, max_iter=10)
# ----> 6     kmeanModel.fit(tickers_scaled)
#       7     distortions.append(kmeanModel.inertia_)
#       8     if k > 1:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tslearn\clustering\kmeans.py:780, in TimeSeriesKMeans.fit(self, X, y)
#     778     print("Init %d" % (n_successful + 1))
#     779 n_attempts += 1
# --> 780 self._fit_one_init(X_, x_squared_norms, rs)
#     781 if self.inertia_ < min_inertia:
#     782     best_correct_centroids = self.cluster_centers_.copy()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tslearn\clustering\kmeans.py:665, in TimeSeriesKMeans._fit_one_init(self, X, x_squared_norms, rs)
#     663 if self.verbose:
#     664     print("%.3f" % self.inertia_, end=" --> ")
# --> 665 self._update_centroids(X)
#     667 if numpy.abs(old_inertia - self.inertia_) < self.tol:
#     668     break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tslearn\clustering\kmeans.py:713, in TimeSeriesKMeans._update_centroids(self, X)
#     711 for k in range(self.n_clusters):
#     712     if self.metric == "dtw":
# --> 713         self.cluster_centers_[k] = dtw_barycenter_averaging(
#     714             X=X[self.labels_ == k],
#     715             barycenter_size=None,
#     716             init_barycenter=self.cluster_centers_[k],
#     717             metric_params=metric_params,
#     718             verbose=False)
#     719     elif self.metric == "softdtw":
#     720         self.cluster_centers_[k] = softdtw_barycenter(
#     721             X=X[self.labels_ == k],
#     722             max_iter=self.max_iter_barycenter,
#     723             init=self.cluster_centers_[k],
#     724             **metric_params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tslearn\barycenters\dba.py:498, in dtw_barycenter_averaging(X, barycenter_size, init_barycenter, max_iter, tol, weights, metric_params, verbose, n_init)
#     496 if verbose:
#     497     print("Attempt {}".format(i + 1))
# --> 498 bary, loss = dtw_barycenter_averaging_one_init(
#     499     X=X,
#     500     barycenter_size=barycenter_size,
#     501     init_barycenter=init_barycenter,
#     502     max_iter=max_iter,
#     503     tol=tol,
#     504     weights=weights,
#     505     metric_params=metric_params,
#     506     verbose=verbose
#     507 )
#     508 if loss < best_cost:
#     509     best_cost = loss
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tslearn\barycenters\dba.py:590, in dtw_barycenter_averaging_one_init(X, barycenter_size, init_barycenter, max_iter, tol, weights, metric_params, verbose)
#     588 cost_prev, cost = numpy.inf, numpy.inf
#     589 for it in range(max_iter):
# --> 590     list_p_k, cost = _mm_assignment(X_, barycenter, weights, metric_params)
#     591     diag_sum_v_k, list_w_k = _mm_valence_warping(list_p_k, barycenter_size,
#     592                                                  weights)
#     593     if verbose:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tslearn\barycenters\dba.py:214, in _mm_assignment(X, barycenter, weights, metric_params)
#     212 list_p_k = []
#     213 for i in range(n):
# --> 214     path, dist_i = dtw_path(barycenter, X[i], **metric_params)
#     215     cost += dist_i ** 2 * weights[i]
#     216     list_p_k.append(path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tslearn\metrics\dtw_variants.py:193, in dtw_path(s1, s2, global_constraint, sakoe_chiba_radius, itakura_max_slope)
#     190 s2 = to_time_series(s2, remove_nans=True)
#     192 if len(s1) == 0 or len(s2) == 0:
# --> 193     raise ValueError("One of the input time series contains only nans or has zero length.")
#     195 mask = compute_mask(
#     196     s1, s2, GLOBAL_CONSTRAINT_CODE[global_constraint],
#     197     sakoe_chiba_radius, itakura_max_slope
#     198 )
#     199 acc_cost_mat = njit_accumulated_matrix(s1, s2, mask=mask)
#
# ValueError: One of the input time series contains only nans or has zero length.
